# %% [markdown]
# #### REQUESTS y BEAUTIFULSOUP

# %%
pip install requests

#HACE PETICIONES HTTP
# Out:
#   Cell In[7], line 1
#     pip install requests
#         ^
# SyntaxError: invalid syntax

# %%
pip install beautifulsoup

#EXTRAE INFORMACIÓN

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ##### Enviar petición HTTP para extraer código de fuente de la página

# %%
page=requests.get("http://books.toscrape.com/")
soup= BeautifulSoup(page.text,'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en-us">
#  <!--<![endif]-->
#  <head>
#   <title>
#    All products | Books to Scrape - Sandbox
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="24th Jun 2016 09:29" name="created"/>
#   <meta content="" name="description"/>
#   <meta content="width=device-width" name="viewport"/>
#   <meta content="NOARCHIVE,NOCACHE" name="robots"/>
#   <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
#   <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
#   <link href="static/oscar/favicon.ico" rel="shortcut icon"/>
# ...

# %%
titulo_items= soup.find_all('h3')

 titulos=[]
for items in titulo_items:
    titulo=items.a #accede a la etiqueta a
    titulos.append(titulo['title'])#da con la etiqueta de title directamente
    
print(titulo_items)
print(titulos)
# Out:
# [<h3><a href="catalogue/a-light-in-the-attic_1000/index.html" title="A Light in the Attic">A Light in the ...</a></h3>, <h3><a href="catalogue/tipping-the-velvet_999/index.html" title="Tipping the Velvet">Tipping the Velvet</a></h3>, <h3><a href="catalogue/soumission_998/index.html" title="Soumission">Soumission</a></h3>, <h3><a href="catalogue/sharp-objects_997/index.html" title="Sharp Objects">Sharp Objects</a></h3>, <h3><a href="catalogue/sapiens-a-brief-history-of-humankind_996/index.html" title="Sapiens: A Brief History of Humankind">Sapiens: A Brief History ...</a></h3>, <h3><a href="catalogue/the-requiem-red_995/index.html" title="The Requiem Red">The Requiem Red</a></h3>, <h3><a href="catalogue/the-dirty-little-secrets-of-getting-your-dream-job_994/index.html" title="The Dirty Little Secrets of Getting Your Dream Job">The Dirty Little Secrets ...</a></h3>, <h3><a href="catalogue/the-coming-woman-a-novel-based-on-the-life-of-the-infamous-feminist-victoria-woodhull_993/index.ht
# ...

# %%
titulos

# %%
precios=[]

precio_items= soup.find_all('p',class_="price_color")

for item in precio_items:
    precio=item.text #se refiere unicamente a la parte de textos
    precios.append(precio)


print(precio_items)
print (precios)
# Out:
# [<p class="price_color">Â£51.77</p>, <p class="price_color">Â£53.74</p>, <p class="price_color">Â£50.10</p>, <p class="price_color">Â£47.82</p>, <p class="price_color">Â£54.23</p>, <p class="price_color">Â£22.65</p>, <p class="price_color">Â£33.34</p>, <p class="price_color">Â£17.93</p>, <p class="price_color">Â£22.60</p>, <p class="price_color">Â£52.15</p>, <p class="price_color">Â£13.99</p>, <p class="price_color">Â£20.66</p>, <p class="price_color">Â£17.46</p>, <p class="price_color">Â£52.29</p>, <p class="price_color">Â£35.02</p>, <p class="price_color">Â£57.25</p>, <p class="price_color">Â£23.88</p>, <p class="price_color">Â£37.59</p>, <p class="price_color">Â£51.33</p>, <p class="price_color">Â£45.17</p>]
# ['Â£51.77', 'Â£53.74', 'Â£50.10', 'Â£47.82', 'Â£54.23', 'Â£22.65', 'Â£33.34', 'Â£17.93', 'Â£22.60', 'Â£52.15', 'Â£13.99', 'Â£20.66', 'Â£17.46', 'Â£52.29', 'Â£35.02', 'Â£57.25', 'Â£23.88', 'Â£37.59', 'Â£51.33', 'Â£45.17']

# %%
precios

# %%
existencias=[]

existencia_items=soup.find_all('p',class_="instock availability")
print(existencia_items)
for item in existencia_items:
    existencia=item.text
    existencias.append(existencia)
# Out:
# [<p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>, <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>, <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>, <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>, <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>, <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>, <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>, <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>, <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>, <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>, <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# ...

# %%
existencias
# Out:
# ['\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n']

# %%
ratings=[]
rating_items=soup.find_all('p',class_="star-rating")
print(rating_items)

for item in rating_items:
    rating=item['class'][1]
    ratings.append(rating)

print(ratings)
# Out:
# [<p class="star-rating Three">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating One">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating One">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating Four">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating Five">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating One">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# ...

# %%
ratings

# %%
import pandas as pd

# %%
data={
    'Título':titulos,
    'Precio':precios,
    'Rating':ratings,
    'Existencia':existencias
}

df=pd.DataFrame(data)

print(df)

# %%
df

# %% [markdown]
# #####  Extraer datos relevantes

# %%
url=requests.get("http://books.toscrape.com/")
soup= BeautifulSoup(url.text,'html.parser')

# %%
images_item= soup.find_all('img',class_="thumbnail")
images=[]
for item in images_item:
    image=item['src'] #accede directamente a la propiedad source 
    images.append("http://books.toscrape.com/"+image) #concatena el url con el source
    
print (images)
# Out:
# ['http://books.toscrape.com/media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg', 'http://books.toscrape.com/media/cache/26/0c/260c6ae16bce31c8f8c95daddd9f4a1c.jpg', 'http://books.toscrape.com/media/cache/3e/ef/3eef99c9d9adef34639f510662022830.jpg', 'http://books.toscrape.com/media/cache/32/51/3251cf3a3412f53f339e42cac2134093.jpg', 'http://books.toscrape.com/media/cache/be/a5/bea5697f2534a2f86a3ef27b5a8c12a6.jpg', 'http://books.toscrape.com/media/cache/68/33/68339b4c9bc034267e1da611ab3b34f8.jpg', 'http://books.toscrape.com/media/cache/92/27/92274a95b7c251fea59a2b8a78275ab4.jpg', 'http://books.toscrape.com/media/cache/3d/54/3d54940e57e662c4dd1f3ff00c78cc64.jpg', 'http://books.toscrape.com/media/cache/66/88/66883b91f6804b2323c8369331cb7dd1.jpg', 'http://books.toscrape.com/media/cache/58/46/5846057e28022268153beff6d352b06c.jpg', 'http://books.toscrape.com/media/cache/be/f4/bef44da28c98f905a3ebec0b87be8530.jpg', 'http://books.toscrape.com/media/cache/10/48/1048f63d3b5061cd2f424d20b3f9
# ...

# %% [markdown]
# ######  Paginación

# %%
import requests
from bs4 import BeautifulSoup

# %%
def obtener_contenido_pagina(url):
    response=requests.get(url)
    return response.content

# %%
def analizar_contenido_html(html):
    return BeautifulSoup(html,'html.parser')

# %%
def procesar_pagina():
    data=[]

    titulos=[]
    precios=[]
    existencias=[]
    ratings=[]

    titulo_items= soup.find_all('h3')

    for items in titulo_items:
        titulo=items.a #accede a la etiqueta a
        titulos.append(titulo['title'])
        
    precio_items= soup.find_all('p',class_="price_color")

    for item in precio_items:
        precio=item.text #se refiere unicamente a la parte de textos
        precios.append(precio)

    existencia_items=soup.find_all('p',class_="instock availability")

    for item in existencia_items:
        existencia=item.text
        existencias.append(existencia)


    rating_items=soup.find_all('p',class_="star-rating")

    for item in rating_items:
        rating=item['class'][1]
        ratings.append(rating)


    data={
        'Título':titulos,
        'Precio':precios,
        'Rating':ratings,
        'Existencia':existencias
    }

    df=pd.DataFrame(data)

# %%
def manejar_paginacion(url_base,num_paginas):
    for i in range(1,num_paginas+1):
        url=url_base+'/page'+str(i)+'.html'#actualiza la url base con el num de página
        contenido_pagina=obtener_contenido_pagina(url)
        soup=analizar_contenido_html(contenido_pagina)
        procesar_pagina(soup)

# %%
url_base="http://books.toscrape.com/catalogue/category/books/mystery_3/index.html"
num_paginas=20

manejar_paginacion(url_base,num_paginas)

# %%
df

# %% [markdown]
# ###### Expresiones regulares

# %%
html=requests.get('http://books.toscrape.com/')
soup=BeautifulSoup(html.text,'html.parser')

# %%
import re

item=soup.select('li.current')

patron=r'Page (\d+) of (\d+)'

concuerda= re.search(patron,html.text)

print(concuerda)

if concuerda:
    page_number=int(concuerda.group(1))
    total_pages=int(concuerda.group(2))
    print(page_number,total_pages)
# Out:
# <re.Match object; span=(49748, 49760), match='Page 1 of 50'>
# 1 50

# %%
url_base="http://books.toscrape.com/index.html"
num_paginas=total_pages

manejar_paginacion(url_base,num_paginas)

# %%
import re

texto="Hola, mi número de telef"

# %% [markdown]
# ##### Ejercicio Cyberpuerta

# %%
'Peticiones http'
page=requests.get("https://www.cyberpuerta.mx/")
soup= BeautifulSoup(page.text,'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE HTML>
# <html lang="es">
#  <head>
#   <link href="https://www.cyberpuerta.mx/out/generated/cms-pages.css?1593624763" rel="stylesheet" type="text/css"/>
#   <link href="https://www.cyberpuerta.mx/out/cyberpuertaV5/src/css/emslider2.css?1690311918" rel="stylesheet" type="text/css"/>
#   <link href="https://www.cyberpuerta.mx/out/cyberpuertaV5/src/css/oxwidget_headerlogin.css?1690311918" rel="stylesheet" type="text/css"/>
#   <link href="https://www.cyberpuerta.mx/out/cyberpuertaV5/src/css/oxwidget_headernotice.css?1690311918" rel="stylesheet" type="text/css"/>
#   <link href="https://www.cyberpuerta.mx/out/cyberpuertaV5/src/css/oxwidget_headercompare.css?1690311918" rel="stylesheet" type="text/css"/>
#   <link href="https://www.cyberpuerta.mx/out/cyberpuertaV5/src/css/oxwidget_headerhelp.css?1690311918" rel="stylesheet" type="text/css"/>
# ...

# %%
items_find=soup.find_all('div',class_='emproduct_cptitleBox')
print(items_find)

titulos_destacados=[]

for item in items_find:
    titulo=item.a #se refiere unicamente a la parte de textos
    titulos_destacados.append(titulo['title'])
# Out:
# [<div class="emproduct_cptitleBox">
# <a ,="" 75hz,="" class="emproduct_title cpGaProdemstartpagenew-1" data-text="" data-truncate="Monitor Qian QM2151F LED 21.5" full="" hd,="" hdmi="" href="https://www.cyberpuerta.mx/Computo-Hardware/Monitores/Monitores/Monitor-Qian-QM2151F-LED-21-5-Full-HD-75Hz-HDMI-Negro-Plata.html" id="emstartpagenew-1" negro="" plata"="" title='Monitor Qian QM2151F LED 21.5", Full HD, 75Hz, HDMI Negro/Plata'>
# <span>Monitor Qian QM2151F LED 21.5", Full HD, 75Hz, HDMI Negro/Plata</span>
# </a>
# </div>, <div class="emproduct_cptitleBox">
# ...

# %%
titulos_destacados
# Out:
# ['Monitor Qian QM2151F LED 21.5", Full HD, 75Hz, HDMI Negro/Plata',
#  'Fuente de Poder Cooler Master MWE GOLD 850 V2 FULL MODULAR 80 PLUS Gold, 24-pines ATX, 120mm, 850W',
#  'Monitor LG 29WP500-B LCD 29", Full HD, UltraWide, FreeSync, 75Hz, HDMI, Negro',
#  'Tarjeta de Video MSI NVIDIA GeForce RTX 3060 Ventus 3X 12G OC, 12GB 192-bit GDDR6, PCI Express 4.0',
#  'Procesador AMD Ryzen 5 5500, S-AM4, 3.60GHz, Six-Core, 16MB L3 Caché - incluye Disipador Wraith Stealth',
#  'Memoria RAM XPG Lancer DDR5, 5200MHz, 16GB, ECC, CL38, XMP',
#  'Procesador AMD Ryzen 5 4600G Radeon Graphics, S-AM4, 3.70GHz, Six-Core, 8MB L3 Caché - con Disipador Wraith Stealth',
#  "Disco Duro Interno Seagate Barracuda 3.5'', 1TB, SATA III, 6 Gbit/s, 7200RPM, 64MB Cache",
#  'SSD Team Group MP34 NVMe 1TB, PCI Express 3.0, M.2',
#  'Tarjeta Madre AORUS Micro ATX B550M ELITE, S-AM4, AMD B550, HDMI, 128GB DDR4 para AMD ― Requiere Actualización de BIOS para la Serie Ryzen 5000',
# ...

# %%
precio_found=soup.find_all('label',class_="price")
print(precio_found)

precios=[]
 
for item in precio_found:
    precio=item.text
    precios.append(precio)
# Out:
# [<label class="price">
# $1,469.00
# </label>, <label class="price">
# $1,849.00
# </label>, <label class="price">
# $3,699.00
# </label>, <label class="price">
# $5,619.00
# </label>, <label class="price">
# $1,429.00
# </label>, <label class="price">
# $849.00
# </label>, <label class="price">
# $1,429.00
# </label>, <label class="price">
# $649.00
# </label>, <label class="price">
# $669.00
# </label>, <label class="price">
# $2,149.00
# </label>, <label class="price">
# $689.00
# </label>, <label class="price">
# $3,089.00
# </label>]

# %%
precios=[item.strip() for item in precios]
precios
# Out:
# ['$1,469.00',
#  '$1,849.00',
#  '$3,699.00',
#  '$5,619.00',
#  '$1,429.00',
#  '$849.00',
#  '$1,429.00',
#  '$649.00',
#  '$669.00',
#  '$2,149.00',
#  '$689.00',
#  '$3,089.00']

# %%
envio_find=soup.find_all('span',class_='deliveryvalue')
print(envio_find)

envios=[]
for item in envio_find:
    precio_envio=item.text
    envios.append(precio_envio)
# Out:
# [<span class="deliveryvalue">$144.00</span>, <span class="deliveryvalue">$99.00</span>, <span class="deliveryvalue">$164.00</span>, <span class="deliveryvalue">$99.00</span>, <span class="deliveryvalue">$99.00</span>, <span class="deliveryvalue">$99.00</span>, <span class="deliveryvalue">$99.00</span>, <span class="deliveryvalue">$99.00</span>, <span class="deliveryvalue">$99.00</span>, <span class="deliveryvalue">$99.00</span>, <span class="deliveryvalue">$99.00</span>, <span class="deliveryvalue">$99.00</span>]

# %%
envios
# Out:
# ['$144.00',
#  '$99.00',
#  '$164.00',
#  '$99.00',
#  '$99.00',
#  '$99.00',
#  '$99.00',
#  '$99.00',
#  '$99.00',
#  '$99.00',
#  '$99.00',
#  '$99.00']

# %%
piezas_find=soup.find_all('div',class_="emstock")
print(piezas_find)

piezas_dispo=[]

for item in piezas_find:
    piezas=item.span.text
    piezas_dispo.append(piezas)
# Out:
# [<div class="emstock">            Disponibles:
# <span>120</span>
# pzas.
# </div>, <div class="emstock">            Disponibles:
# <span>41</span>
# pzas.
# </div>, <div class="emstock">            Disponibles:
# <span>80</span>
# pzas.
# </div>, <div class="emstock">            Disponibles:
# <span>21</span>
# pzas.
# </div>, <div class="emstock">            Disponibles:
# <span>6</span>
# pzas.
# </div>, <div class="emstock">            Disponibles:
# <span>42</span>
# pzas.
# </div>, <div class="emstock">            Disponibles:
# <span>463</span>
# pzas.
# </div>, <div class="emstock">            Disponibles:
# <span>66</span>
# pzas.
# </div>, <div class="emstock">            Disponibles:
# <span>64</span>
# pzas.
# </div>, <div class="emstock">            Disponibles:
# <span>171</span>
# pzas.
# </div>, <div class="emstock">            Disponibles:
# <span>165</span>
# pzas.
# </div>, <div class="emstock">            Disponibles:
# <span>79</span>
# pzas.
# </div>]

# %%
piezas_dispo
# Out:
# ['120', '41', '80', '21', '6', '42', '463', '66', '64', '171', '165', '79']

# %%
import pandas as pd

# %%
data_destacados={
    'Artículo':titulos_destacados,
    'Precio':precios,
    'Costo de envío':envios,
    'Piezas disponibles':piezas_dispo
}

df_destacados=pd.DataFrame(data_destacados)

print(df_destacados)
# Out:
#                                              Artículo         Precio  \
# 0   Monitor Qian QM2151F LED 21.5", Full HD, 75Hz,...  \n$1,469.00\n
# 1   Fuente de Poder Cooler Master MWE GOLD 850 V2 ...  \n$1,849.00\n
# 2   Monitor LG 29WP500-B LCD 29", Full HD, UltraWi...  \n$3,699.00\n
# 3   Tarjeta de Video MSI NVIDIA GeForce RTX 3060 V...  \n$5,619.00\n
# 4   Procesador AMD Ryzen 5 5500, S-AM4, 3.60GHz, S...  \n$1,429.00\n
# 5   Memoria RAM XPG Lancer DDR5, 5200MHz, 16GB, EC...    \n$849.00\n
# 6   Procesador AMD Ryzen 5 4600G Radeon Graphics, ...  \n$1,429.00\n
# 7   Disco Duro Interno Seagate Barracuda 3.5'', 1T...    \n$649.00\n
# 8   SSD Team Group MP34 NVMe 1TB, PCI Express 3.0,...    \n$669.00\n
# 9   Tarjeta Madre AORUS Micro ATX B550M ELITE, S-A...  \n$2,149.00\n
# 10  Fuente de Poder Gigabyte P450B 80 PLUS Bronze,...    \n$689.00\n
# 11  Tarjeta Madre MSI ATX MAG B550 TOMAHAWK, S-AM4...  \n$3,089.00\n
#
#    Costo de envío Piezas disponibles
# ...

# %%
import matplotlib as plt
import matplotlib.pyplot as plt

# %%
precios_limpio = []
for precio in precios:
    precio_limpio = float(precio.replace('$', '').replace(',', ''))
    precios_limpio.append(precio_limpio)

# %%
import numpy as np
x=df_destacados.index

y= precios_limpio


plt.bar(x,y)

plt.show()
